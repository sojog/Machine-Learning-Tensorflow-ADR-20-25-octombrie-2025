# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# df = pd.read_csv("https://github.com/sojog/Machine-Learning-Tensorflow-ADR-20-25-octombrie-2025/blob/main/Ziua2/date_inghetata.csv?raw=true")

df = pd.read_csv("date_inghetata.csv")

df
# Out:
#      temperatura  vanzari      luna zi_saptamana
# 0              8       25  ianuarie         luni
# 1             10       35  ianuarie        marti
# 2             12       45  ianuarie     miercuri
# 3             15       55  ianuarie          joi
# 4             18       75  ianuarie       vineri
# ..           ...      ...       ...          ...
# 233           33      168       mai     miercuri
# 234           35      182       mai          joi
# 235           37      195       mai       vineri
# 236           39      208       mai      sambata
# 237           41      222       mai    duminica
#
# [238 rows x 4 columns]

# %%
df.plot.scatter(x="temperatura", y="vanzari")
# Out:
# <Axes: xlabel='temperatura', ylabel='vanzari'>

# %%
plt.scatter(df["temperatura"], df["vanzari"])

# %%
# Separarea in variabila dependenta si independenta
x = df["temperatura"]
y = df["vanzari"]

# %%
x = df.temperatura
y = df.vanzari

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.22)

# %%
plt.scatter(x, y)

# %%
plt.scatter(x_train, y_train)
plt.scatter(x_test, y_test)

# %%
plt.scatter(x_train, y_train, c="green")
plt.scatter(x_test, y_test, c="red")

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train.to_numpy().reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
x_train.to_numpy()
# Out:
# array([17, 38, 25, 34, 29, 23, 35, 13, 43, 25, 29, 22, 21, 40, 20, 40, 33,
#        26, 22, 41, 31, 33, 28, 22, 39, 32, 37, 28, 44, 39, 29, 30, 17, 27,
#        10, 22, 31, 24, 39, 42, 41, 15, 32, 28, 26, 26, 12, 11, 40, 20, 18,
#        24, 27, 34, 14, 18, 25, 39, 16, 15, 39, 21, 27, 31, 37, 33, 43, 38,
#        19, 44, 43, 41, 23, 15, 40, 36, 29, 24, 24, 17, 25, 37, 25, 32, 28,
#        28, 23, 37, 42, 34, 26, 26, 30, 19, 44, 29, 33, 29, 31, 27, 19, 25,
#        45, 34, 18, 43, 26, 38, 24, 19, 27, 30, 24, 32, 20, 22, 28, 16, 23,
#        41, 40, 38, 23, 42, 12, 45, 31, 33, 20, 22, 45, 44, 36, 16, 38, 33,
#        21, 27, 37, 35, 31, 24, 21, 24, 13, 35, 23, 25, 15, 23, 35, 35, 21,
#        39, 29, 30,  8, 27, 23, 36, 41, 20, 17, 38, 16, 32, 29, 37, 35, 22,
#        18, 41, 42, 14,  9, 42, 32, 22, 30, 36, 24, 22, 35, 32, 30])

# %%
x_train.to_numpy().reshape(-1, 1)
# Out:
# array([[17],
#        [38],
#        [25],
#        [34],
#        [29],
#        [23],
#        [35],
#        [13],
#        [43],
#        [25],
#        [29],
#        [22],
#        [21],
#        [40],
#        [20],
#        [40],
#        [33],
#        [26],
#        [22],
#        [41],
#        [31],
#        [33],
#        [28],
#        [22],
#        [39],
#        [32],
#        [37],
#        [28],
#        [44],
#        [39],
#        [29],
#        [30],
#        [17],
#        [27],
#        [10],
#        [22],
#        [31],
#        [24],
#        [39],
#        [42],
#        [41],
#        [15],
#        [32],
#        [28],
#        [26],
#        [26],
#        [12],
#        [11],
#        [40],
#        [20],
#        [18],
#        [24],
#        [27],
#        [34],
#        [14],
#        [18],
#        [25],
#        [39],
#        [16],
#        [15],
#        [39],
#        [21],
#        [27],
#        [31],
#        [37],
#        [33],
# ...

# %%
model.coef_, model.intercept_
# Out:
# (array([7.26158146]), np.float64(-60.69894841624338))

# %%
plt.scatter(x_train, y_train, c="green")
plt.scatter(x_test, y_test, c="red")

a = model.coef_
b = model.intercept_

plt.plot(x, a * x + b, c="black")

# %%
model.score(x_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.984193385508847
