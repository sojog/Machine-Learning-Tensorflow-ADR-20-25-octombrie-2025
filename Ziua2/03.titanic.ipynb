# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv("titanic/train.csv", index_col="PassengerId")
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
test_df = pd.read_csv("titanic/test.csv", index_col="PassengerId")
test_df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
test_results_df = pd.read_csv("titanic/gender_submission.csv", index_col="PassengerId")
test_results_df
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 1 columns]

# %%
train_df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
train_df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
type(train_df.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_df.describe().keys()
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
train_df["Sex"]
# Out:
# PassengerId
# 1        male
# 2      female
# 3      female
# 4      female
# 5        male
#         ...
# 887      male
# 888    female
# 889    female
# 890      male
# 891      male
# Name: Sex, Length: 891, dtype: object

# %%
train_df["Sex"].unique(), train_df["Sex"].nunique()
# Out:
# (array(['male', 'female'], dtype=object), 2)

# %%
train_df["Gen"] = train_df["Sex"] == "male"
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train_df["Gen"] = train_df["Sex"].map({"female": 0, "male":1})
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#               Gen
# count  891.000000
# mean     0.647587
# std      0.477990
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
len(train_df["Name"].unique())
# Out:
# 891

# %%
len(train_df["Ticket"].unique())
# Out:
# 681

# %%
len(train_df["Fare"].unique())
# Out:
# 248

# %%
len(train_df["Cabin"].unique())
# Out:
# 148

# %%
train_df["Embarked"].nunique(), train_df["Embarked"].unique()
# Out:
# (3, array(['S', 'C', 'Q', nan], dtype=object))

# %%
train_df["Embarked"] = train_df["Embarked"].map({"S": 0, "C":1, "Q":2})

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train_df["Cabin"].unique(), train_df["Cabin"].nunique()
# Out:
# (array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#         'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#         'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#         'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#         'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#         'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#         'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#         'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#         'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#         'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#         'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#         'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#         'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
set([str(i)[0] for i in train_df["Cabin"].unique()])
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'n'}

# %%
train_df["Cabin_LETTER"] = train_df["Cabin"].astype(np.str_).str[0]

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train_df["Cabin_LETTER"].unique()
# Out:
# array(['n', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
train_df["Cabin_LETTER"] = encoder.fit_transform(train_df["Cabin_LETTER"])
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train_df.dtypes
# Out:
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked        float64
# Gen               int64
# Cabin_LETTER      int64
# dtype: object

# %%
train_df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Gen', 'Cabin_LETTER'],
#       dtype='object')

# %%
train_numbers_only_df = train_df[['Survived', 'Pclass',  'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Gen', 'Cabin_LETTER']]

train_numbers_only_df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Gen  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500       0.0    1
# 2                   1       1  38.0      1      0  71.2833       1.0    0
# 3                   1       3  26.0      0      0   7.9250       0.0    0
# 4                   1       1  35.0      1      0  53.1000       0.0    0
# 5                   0       3  35.0      0      0   8.0500       0.0    1
# ...               ...     ...   ...    ...    ...      ...       ...  ...
# 887                 0       2  27.0      0      0  13.0000       0.0    1
# 888                 1       1  19.0      0      0  30.0000       0.0    0
# 889                 0       3   NaN      1      2  23.4500       0.0    0
# 890                 1       1  26.0      0      0  30.0000       1.0    1
# 891                 0       3  32.0      0      0   7.7500       2.0    1
#
#              Cabin_LETTER
# PassengerId
# ...

# %%
train_numbers_only_df.corr()
# Out:
#               Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived      1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass       -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age          -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp        -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch         0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare          0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# Embarked      0.108669  0.043835  0.012186 -0.060606 -0.079320  0.063462
# Gen          -0.543351  0.131900  0.093254 -0.114631 -0.245489 -0.182333
# Cabin_LETTER -0.301116  0.746616 -0.267270  0.041540 -0.032548 -0.523013
#
#               Embarked       Gen  Cabin_LETTER
# Survived      0.108669 -0.543351     -0.301116
# Pclass        0.043835  0.131900      0.746616
# Age           0.012186  0.093254     -0.267270
# SibSp        -0.060606 -0.114631      0.041540
# ...

# %% [markdown]
# # ! pip install seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(train_numbers_only_df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(train_numbers_only_df.corr(), cmap="Spectral")
# Out:
# <Axes: >

# %%
sns.heatmap(train_numbers_only_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.scatter(train_numbers_only_df["Age"], train_numbers_only_df["Gen"])

# %%
plt.scatter(train_numbers_only_df["Age"], train_numbers_only_df["Gen"], c=train_numbers_only_df["Survived"]==1)

# %%
plt.rcParams["figure.figsize"] # [6.4, 4.8]
# Out:
# [6.4, 4.8]

# %%
plt.rcParams["figure.figsize"] = [12.8, 4.8]

# %%
plt.scatter(train_numbers_only_df["Age"], train_numbers_only_df["Gen"], c=train_numbers_only_df["Survived"]==1);
plt.xlabel("Varsta");
plt.ylabel("GEN - 1 (barbati), 0 (femei)")
# Out:
# Text(0, 0.5, 'GEN - 1 (barbati), 0 (femei)')

# %%
plt.rcParams["figure.figsize"] = [6.4, 4.8]
sns.heatmap(train_numbers_only_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"] = [6.4, 4.8]
sns.heatmap(train_numbers_only_df[train_numbers_only_df["Age"] > 12].corr(), cmap="coolwarm")
# Out:
# <Axes: >
