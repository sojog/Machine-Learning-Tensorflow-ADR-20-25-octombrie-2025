# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Boston.csv", index_col=0)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 1       15.3  396.90   4.98  24.0
# 2       17.8  396.90   9.14  21.6
# 3       17.8  392.83   4.03  34.7
# 4       18.7  394.63   2.94  33.4
# 5       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 502     21.0  391.99   9.67  22.4
# 503     21.0  396.90   9.08  20.6
# 504     21.0  396.90   5.64  23.9
# 505     21.0  393.45   6.48  22.0
# 506     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# Afisarea primelor 5 elemente

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 1  396.90   4.98  24.0
# 2  396.90   9.14  21.6
# 3  392.83   4.03  34.7
# 4  394.63   2.94  33.4
# 5  396.90   5.33  36.2

# %% [markdown]
# Afisarea primelor 2 elemente

# %%
df.head(2)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#    black  lstat  medv
# 1  396.9   4.98  24.0
# 2  396.9   9.14  21.6

# %% [markdown]
# Afisarea ultimelor 5 elemente

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 502  391.99   9.67  22.4
# 503  396.90   9.08  20.6
# 504  396.90   5.64  23.9
# 505  393.45   6.48  22.0
# 506  396.90   7.88  11.9

# %%
len(df.keys())
# Out:
# 14

# %%
df.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
x = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black', 'lstat']]
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 1       15.3  396.90   4.98
# 2       17.8  396.90   9.14
# 3       17.8  392.83   4.03
# 4       18.7  394.63   2.94
# 5       18.7  396.90   5.33
# ..       ...     ...    ...
# 502     21.0  391.99   9.67
# 503     21.0  396.90   9.08
# 504     21.0  396.90   5.64
# 505     21.0  393.45   6.48
# 506     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y = df [  ['medv'] ]
y
# Out:
#      medv
# 1    24.0
# 2    21.6
# 3    34.7
# 4    33.4
# 5    36.2
# ..    ...
# 502  22.4
# 503  20.6
# 504  23.9
# 505  22.0
# 506  11.9
#
# [506 rows x 1 columns]

# %%
x.shape, y.shape
# Out:
# ((506, 13), (506, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 420  11.81230   0.0  18.10     0  0.7180  6.824  76.5  1.7940   24  666
# 193   0.08664  45.0   3.44     0  0.4370  7.178  26.3  6.4798    5  398
# 326   0.19186   0.0   7.38     0  0.4930  6.431  14.7  5.4159    5  287
# 241   0.11329  30.0   4.93     0  0.4280  6.897  54.3  6.3361    6  300
# 154   2.14918   0.0  19.58     0  0.8710  5.709  98.5  1.6232    5  403
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 334   0.05083   0.0   5.19     0  0.5150  6.316  38.1  6.4584    5  224
# 281   0.03578  20.0   3.33     0  0.4429  7.820  64.5  4.6947    5  216
# 101   0.14866   0.0   8.56     0  0.5200  6.727  79.9  2.7778    5  384
# 427  12.24720   0.0  18.10     0  0.5840  5.837  59.7  1.9976   24  666
# 141   0.29090   0.0  21.89     0  0.6240  6.174  93.6  1.6119    4  437
#
#      ptratio   black  lstat
# 420     20.2   48.45  22.74
# 193     15.2  390.49   2.87
# 326     19.6  393.68   5.08
# 241     16.6  391.25  11.38
# 154     14.7  261.95  15.79
# ..       ...     ...    ...
# 334     20.2  389.71   5.68
# 281     14.9  387.31   3.76
# 101     20.9  394.76   9.42
# 427     20.2   24.65  15.69
# 141     21.2  388.08  24.16
#
# [404 rows x 13 columns]

# %%
x_test
# Out:
#         crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 115  0.14231   0.0  10.01     0  0.547  6.254   84.2  2.2565    6  432
# 329  0.06617   0.0   3.24     0  0.460  5.868   25.8  5.2146    4  430
# 59   0.15445  25.0   5.13     0  0.453  6.145   29.2  7.8148    8  284
# 24   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 275  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 134  0.32982   0.0  21.89     0  0.624  5.822   95.4  2.4699    4  437
# 248  0.19657  22.0   5.86     0  0.431  6.226   79.2  8.0555    7  330
# 229  0.29819   0.0   6.20     0  0.504  7.686   17.0  3.3751    8  307
# 13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 300  0.05561  70.0   2.24     0  0.400  7.041   10.0  7.8278    5  358
#
#      ptratio   black  lstat
# 115     17.8  388.74  10.45
# 329     16.9  382.44   9.97
# 59      19.7  390.68   6.86
# 24      21.0  394.54  19.88
# 275     17.6  396.90   3.53
# ..       ...     ...    ...
# 134     21.2  388.69  15.03
# 248     19.1  376.14  10.15
# 229     17.4  377.51   3.92
# 13      15.2  390.50  15.71
# 300     14.8  371.58   4.74
#
# [102 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prezis = model.predict(x_test)
y_prezis
# Out:
# array([[25.51276285],
#        [21.0845024 ],
#        [21.47745596],
#        [14.05435446],
#        [35.69062211],
#        [17.69874408],
#        [20.01893665],
#        [27.22383046],
#        [32.34734244],
#        [ 6.60760262],
#        [17.02128259],
#        [25.06121325],
#        [16.46738679],
#        [31.91099081],
#        [17.30349867],
#        [17.34265897],
#        [20.3856731 ],
#        [28.4571322 ],
#        [27.46942045],
#        [19.8196712 ],
#        [18.23266481],
#        [35.83445967],
#        [14.64123804],
#        [13.26416155],
#        [ 8.43892578],
#        [23.24983661],
#        [ 8.98286488],
#        [ 8.78624786],
#        [34.27520541],
#        [19.28027717],
#        [21.11875243],
#        [21.24956593],
#        [25.76989731],
#        [24.64490414],
#        [22.1649272 ],
#        [24.19945652],
#        [30.71136738],
#        [19.38641434],
#        [27.62586582],
#        [22.42543921],
#        [31.54914249],
#        [12.8507383 ],
#        [28.28510962],
#        [24.60336443],
#        [23.78030981],
#        [22.09473204],
#        [14.76700522],
#        [27.45398453],
#        [19.48200273],
#        [33.85089486],
#        [20.79831546],
#        [33.42151619],
#        [26.15795677],
#        [21.74752246],
#        [35.22266402],
#        [19.85056699],
#        [19.77412387],
#        [31.70497409],
#        [17.04916753],
#        [17.08994016],
#        [18.63501194],
#        [33.08678776],
#        [18.66475832],
#        [22.49656026],
#        [21.23441654],
#        [30.43808977],
#        [16.71740616],
#        [21.12394932],
#        [19.39958392],
#        [14.2405325 ],
#        [25.51979212],
#        [15.87356879],
#        [27.21550934],
#        [20.41638019],
#        [13.23243371],
#        [10.20981666],
#        [20.51485838],
#        [19.87360581],
#        [19.90590851],
#        [23.77610335],
#        [10.74567921],
#        [35.17267059],
#        [ 7.03204159],
#        [24.57178821],
#        [36.52258125],
#        [20.94386832],
#        [14.72612838],
#        [ 8.9899468 ],
#        [21.89995986],
#        [25.65286337],
#        [18.12795761],
#        [17.17437845],
#        [23.13872707],
#        [ 5.99920751],
#        [34.89595448],
#        [ 9.24492459],
#        [14.63858939],
#        [15.77205686],
#        [20.13396623],
#        [34.37774785],
#        [20.77723969],
#        [31.91570509]])

# %%
y_test["medv"]
# Out:
# 115    18.5
# 329    19.3
# 59     23.3
# 24     14.5
# 275    32.4
#        ...
# 134    18.4
# 248    20.5
# 229    46.7
# 13     21.7
# 300    29.0
# Name: medv, Length: 102, dtype: float64

# %%
pd.DataFrame (
    {"real":y_test["medv"], "prezis":y_prezis.flatten()}
)
# Out:
#      real     prezis
# 115  18.5  25.512763
# 329  19.3  21.084502
# 59   23.3  21.477456
# 24   14.5  14.054354
# 275  32.4  35.690622
# ..    ...        ...
# 134  18.4  15.772057
# 248  20.5  20.133966
# 229  46.7  34.377748
# 13   21.7  20.777240
# 300  29.0  31.915705
#
# [102 rows x 2 columns]

# %% [markdown]
# ((y_true - y_pred) ** 2).sum()

# %%
model.score(x_test, y_test)
# Out:
# 0.7230559615884604

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x_train, y_train)
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.3830681704857548

# %%
model.score(x_test, y_test)
# Out:
# 0.7230559615884604
