# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://download.microsoft.com/download/3/e/1/3e1c3f21-ecdb-4869-8368-6deba77b919f/kagglecatsanddogs_5340.zip
# Out:
# --2025-10-24 11:13:17--  https://download.microsoft.com/download/3/e/1/3e1c3f21-ecdb-4869-8368-6deba77b919f/kagglecatsanddogs_5340.zip
# Resolving download.microsoft.com (download.microsoft.com)... 184.29.98.57, 2600:1407:3c00:ea3::317f, 2600:1407:3c00:e9b::317f
# Connecting to download.microsoft.com (download.microsoft.com)|184.29.98.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824887076 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_5340.zip’
#
# kagglecatsanddogs_5 100%[===================>] 786.67M   111MB/s    in 9.8s
#
# 2025-10-24 11:13:26 (80.5 MB/s) - ‘kagglecatsanddogs_5340.zip’ saved [824887076/824887076]

# %%
ZIP_PATH = '/content/kagglecatsanddogs_5340.zip'

# %%
import zipfile
archive = zipfile.ZipFile(ZIP_PATH, 'r')

# %%
with zipfile.ZipFile(ZIP_PATH) as zf:
    print(zf.namelist())
    plt.imshow(plt.imread(zf.open('PetImages/Cat/1.jpg')))
# Out:
# ['PetImages/Cat/', 'PetImages/Cat/0.jpg', 'PetImages/Cat/1.jpg', 'PetImages/Cat/10.jpg', 'PetImages/Cat/100.jpg', 'PetImages/Cat/1000.jpg', 'PetImages/Cat/10000.jpg', 'PetImages/Cat/10001.jpg', 'PetImages/Cat/10002.jpg', 'PetImages/Cat/10003.jpg', 'PetImages/Cat/10004.jpg', 'PetImages/Cat/10005.jpg', 'PetImages/Cat/10006.jpg', 'PetImages/Cat/10007.jpg', 'PetImages/Cat/10008.jpg', 'PetImages/Cat/10009.jpg', 'PetImages/Cat/1001.jpg', 'PetImages/Cat/10010.jpg', 'PetImages/Cat/10011.jpg', 'PetImages/Cat/10012.jpg', 'PetImages/Cat/10013.jpg', 'PetImages/Cat/10014.jpg', 'PetImages/Cat/10015.jpg', 'PetImages/Cat/10016.jpg', 'PetImages/Cat/10017.jpg', 'PetImages/Cat/10018.jpg', 'PetImages/Cat/10019.jpg', 'PetImages/Cat/1002.jpg', 'PetImages/Cat/10020.jpg', 'PetImages/Cat/10021.jpg', 'PetImages/Cat/10022.jpg', 'PetImages/Cat/10023.jpg', 'PetImages/Cat/10024.jpg', 'PetImages/Cat/10025.jpg', 'PetImages/Cat/10026.jpg', 'PetImages/Cat/10027.jpg', 'PetImages/Cat/10028.jpg', 'PetImages/Cat/10029.jpg', 'PetImages/Cat/1003.jpg', 'PetImages/Cat/10030.jpg', 'PetImages/Cat/10031.jpg', 'PetImages/Cat/10032.jpg', 'PetImages/Cat/10033.jpg', 'PetImages/Cat/10034.jpg', 'PetImages/Cat/10035.jpg', 'PetImages/Cat/10036.jpg', 'PetImages/Cat/10037.jpg', 'PetImages/Cat/10038.jpg', 'PetImages/Cat/10039.jpg', 'PetImages/Cat/1004.jpg', 'PetImages/Cat/10040.jpg', 'PetImages/Cat/10041.jpg', 'PetImages/Cat/10042.jpg', 'PetImages/Cat/10043.jpg', 'PetImages/Cat/10044.jpg', 'PetImages/Cat/10045.jpg', 'PetImages/Cat/10046.jpg', 'PetImages/Cat/10047.jpg', 'PetImages/Cat/10048.jpg', 'PetImages/Cat/10049.jpg', 'PetImages/Cat/1005.jpg', 'PetImages/Cat/10050.jpg', 'PetImages/Cat/10051.jpg', 'PetImages/Cat/10052.jpg', 'PetImages/Cat/10053.jpg', 'PetImages/Cat/10054.jpg', 'PetImages/Cat/10055.jpg', 'PetImages/Cat/10056.jpg', 'PetImages/Cat/10057.jpg', 'PetImages/Cat/10058.jpg', 'PetImages/Cat/10059.jpg', 'PetImages/Cat/1006.jpg', 'PetImages/Cat/10060.jpg', 'PetImages/Cat/10061.jpg', 'PetImages/Cat/10062.jpg', 'PetImages/Cat/10063.jpg', 'PetImages/Cat/10064.jpg', 'PetImages/Cat/10065.jpg', 'PetImages/Cat/10066.jpg', 'PetImages/Cat/10067.jpg', 'PetImages/Cat/10068.jpg', 'PetImages/Cat/10069.jpg', 'PetImages/Cat/1007.jpg', 'PetImages/Cat/10070.jpg', 'PetImages/Cat/10071.jpg', 'PetImages/Cat/10072.jpg', 'PetImages/Cat/10073.jpg', 'PetImages/Cat/10074.jpg', 'PetImages/Cat/10075.jpg', 'PetImages/Cat/10076.jpg', 'PetImages/Cat/10077.jpg', 'PetImages/Cat/10078.jpg', 'PetImages/Cat/10079.jpg', 'PetImages/Cat/1008.jpg', 'PetImages/Cat/10080.jpg', 'PetImages/Cat/10081.jpg', 'PetImages/Cat/10082.jpg', 'PetImages/Cat/10083.jpg', 'PetImages/Cat/10084.jpg', 'PetImages/Cat/10085.jpg', 'PetImages/Cat/10086.jpg', 'PetImages/Cat/10087.jpg', 'PetImages/Cat/10088.jpg', 'PetImages/Cat/10089.jpg', 'PetImages/Cat/1009.jpg', 'PetImages/Cat/10090.jpg', 'PetImages/Cat/10091.jpg', 'PetImages/Cat/10092.jpg', 'PetImages/Cat/10093.jpg', 'PetImages/Cat/10094.jpg', 'PetImages/Cat/10095.jpg', 'PetImages/Cat/10096.jpg', 'PetImages/Cat/10097.jpg', 'PetImages/Cat/10098.jpg', 'PetImages/Cat/10099.jpg', 'PetImages/Cat/101.jpg', 'PetImages/Cat/1010.jpg', 'PetImages/Cat/10100.jpg', 'PetImages/Cat/10101.jpg', 'PetImages/Cat/10102.jpg', 'PetImages/Cat/10103.jpg', 'PetImages/Cat/10104.jpg', 'PetImages/Cat/10105.jpg', 'PetImages/Cat/10106.jpg', 'PetImages/Cat/10107.jpg', 'PetImages/Cat/10108.jpg', 'PetImages/Cat/10109.jpg', 'PetImages/Cat/1011.jpg', 'PetImages/Cat/10110.jpg', 'PetImages/Cat/10111.jpg', 'PetImages/Cat/10112.jpg', 'PetImages/Cat/10113.jpg', 'PetImages/Cat/10114.jpg', 'PetImages/Cat/10115.jpg', 'PetImages/Cat/10116.jpg', 'PetImages/Cat/10117.jpg', 'PetImages/Cat/10118.jpg', 'PetImages/Cat/10119.jpg', 'PetImages/Cat/1012.jpg', 'PetImages/Cat/10120.jpg', 'PetImages/Cat/10121.jpg', 'PetImages/Cat/10122.jpg', 'PetImages/Cat/10123.jpg', 'PetImages/Cat/10124.jpg', 'PetImages/Cat/10125.jpg', 'PetImages/Cat/10126.jpg', 'PetImages/Cat/10127.jpg', 'PetImages/Cat/10128.jpg', 'PetImages/Cat/10129.jpg', 'PetImages/Ca ...

# %%
with zipfile.ZipFile(ZIP_PATH) as zf:
    print(zf.namelist())
    plt.imshow(plt.imread(zf.open('PetImages/Dog/1.jpg')))
# Out:
# ['PetImages/Cat/', 'PetImages/Cat/0.jpg', 'PetImages/Cat/1.jpg', 'PetImages/Cat/10.jpg', 'PetImages/Cat/100.jpg', 'PetImages/Cat/1000.jpg', 'PetImages/Cat/10000.jpg', 'PetImages/Cat/10001.jpg', 'PetImages/Cat/10002.jpg', 'PetImages/Cat/10003.jpg', 'PetImages/Cat/10004.jpg', 'PetImages/Cat/10005.jpg', 'PetImages/Cat/10006.jpg', 'PetImages/Cat/10007.jpg', 'PetImages/Cat/10008.jpg', 'PetImages/Cat/10009.jpg', 'PetImages/Cat/1001.jpg', 'PetImages/Cat/10010.jpg', 'PetImages/Cat/10011.jpg', 'PetImages/Cat/10012.jpg', 'PetImages/Cat/10013.jpg', 'PetImages/Cat/10014.jpg', 'PetImages/Cat/10015.jpg', 'PetImages/Cat/10016.jpg', 'PetImages/Cat/10017.jpg', 'PetImages/Cat/10018.jpg', 'PetImages/Cat/10019.jpg', 'PetImages/Cat/1002.jpg', 'PetImages/Cat/10020.jpg', 'PetImages/Cat/10021.jpg', 'PetImages/Cat/10022.jpg', 'PetImages/Cat/10023.jpg', 'PetImages/Cat/10024.jpg', 'PetImages/Cat/10025.jpg', 'PetImages/Cat/10026.jpg', 'PetImages/Cat/10027.jpg', 'PetImages/Cat/10028.jpg', 'PetImages/Cat/10029.jpg', 'PetImages/Cat/1003.jpg', 'PetImages/Cat/10030.jpg', 'PetImages/Cat/10031.jpg', 'PetImages/Cat/10032.jpg', 'PetImages/Cat/10033.jpg', 'PetImages/Cat/10034.jpg', 'PetImages/Cat/10035.jpg', 'PetImages/Cat/10036.jpg', 'PetImages/Cat/10037.jpg', 'PetImages/Cat/10038.jpg', 'PetImages/Cat/10039.jpg', 'PetImages/Cat/1004.jpg', 'PetImages/Cat/10040.jpg', 'PetImages/Cat/10041.jpg', 'PetImages/Cat/10042.jpg', 'PetImages/Cat/10043.jpg', 'PetImages/Cat/10044.jpg', 'PetImages/Cat/10045.jpg', 'PetImages/Cat/10046.jpg', 'PetImages/Cat/10047.jpg', 'PetImages/Cat/10048.jpg', 'PetImages/Cat/10049.jpg', 'PetImages/Cat/1005.jpg', 'PetImages/Cat/10050.jpg', 'PetImages/Cat/10051.jpg', 'PetImages/Cat/10052.jpg', 'PetImages/Cat/10053.jpg', 'PetImages/Cat/10054.jpg', 'PetImages/Cat/10055.jpg', 'PetImages/Cat/10056.jpg', 'PetImages/Cat/10057.jpg', 'PetImages/Cat/10058.jpg', 'PetImages/Cat/10059.jpg', 'PetImages/Cat/1006.jpg', 'PetImages/Cat/10060.jpg', 'PetImages/Cat/10061.jpg', 'PetImages/Cat/10062.jpg', 'PetImages/Cat/10063.jpg', 'PetImages/Cat/10064.jpg', 'PetImages/Cat/10065.jpg', 'PetImages/Cat/10066.jpg', 'PetImages/Cat/10067.jpg', 'PetImages/Cat/10068.jpg', 'PetImages/Cat/10069.jpg', 'PetImages/Cat/1007.jpg', 'PetImages/Cat/10070.jpg', 'PetImages/Cat/10071.jpg', 'PetImages/Cat/10072.jpg', 'PetImages/Cat/10073.jpg', 'PetImages/Cat/10074.jpg', 'PetImages/Cat/10075.jpg', 'PetImages/Cat/10076.jpg', 'PetImages/Cat/10077.jpg', 'PetImages/Cat/10078.jpg', 'PetImages/Cat/10079.jpg', 'PetImages/Cat/1008.jpg', 'PetImages/Cat/10080.jpg', 'PetImages/Cat/10081.jpg', 'PetImages/Cat/10082.jpg', 'PetImages/Cat/10083.jpg', 'PetImages/Cat/10084.jpg', 'PetImages/Cat/10085.jpg', 'PetImages/Cat/10086.jpg', 'PetImages/Cat/10087.jpg', 'PetImages/Cat/10088.jpg', 'PetImages/Cat/10089.jpg', 'PetImages/Cat/1009.jpg', 'PetImages/Cat/10090.jpg', 'PetImages/Cat/10091.jpg', 'PetImages/Cat/10092.jpg', 'PetImages/Cat/10093.jpg', 'PetImages/Cat/10094.jpg', 'PetImages/Cat/10095.jpg', 'PetImages/Cat/10096.jpg', 'PetImages/Cat/10097.jpg', 'PetImages/Cat/10098.jpg', 'PetImages/Cat/10099.jpg', 'PetImages/Cat/101.jpg', 'PetImages/Cat/1010.jpg', 'PetImages/Cat/10100.jpg', 'PetImages/Cat/10101.jpg', 'PetImages/Cat/10102.jpg', 'PetImages/Cat/10103.jpg', 'PetImages/Cat/10104.jpg', 'PetImages/Cat/10105.jpg', 'PetImages/Cat/10106.jpg', 'PetImages/Cat/10107.jpg', 'PetImages/Cat/10108.jpg', 'PetImages/Cat/10109.jpg', 'PetImages/Cat/1011.jpg', 'PetImages/Cat/10110.jpg', 'PetImages/Cat/10111.jpg', 'PetImages/Cat/10112.jpg', 'PetImages/Cat/10113.jpg', 'PetImages/Cat/10114.jpg', 'PetImages/Cat/10115.jpg', 'PetImages/Cat/10116.jpg', 'PetImages/Cat/10117.jpg', 'PetImages/Cat/10118.jpg', 'PetImages/Cat/10119.jpg', 'PetImages/Cat/1012.jpg', 'PetImages/Cat/10120.jpg', 'PetImages/Cat/10121.jpg', 'PetImages/Cat/10122.jpg', 'PetImages/Cat/10123.jpg', 'PetImages/Cat/10124.jpg', 'PetImages/Cat/10125.jpg', 'PetImages/Cat/10126.jpg', 'PetImages/Cat/10127.jpg', 'PetImages/Cat/10128.jpg', 'PetImages/Cat/10129.jpg', 'PetImages/Ca ...
